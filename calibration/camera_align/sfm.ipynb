# %%
import os
import logging
from argparse import ArgumentParser

colmap_command = "colmap"
no_gpu = False
skip_matching = False
source_path = '../../example_data'
camera = "PINHOLE"

use_gpu = 1 if not no_gpu else 0

if not skip_matching:
    os.makedirs(source_path + "/distorted/sparse", exist_ok=True)

    ## Feature extraction
    feat_extracton_cmd = colmap_command + " feature_extractor "\
        "--database_path " + source_path + "/distorted/database.db \
        --image_path " + source_path + "/images \
        --ImageReader.single_camera 1 \
        --ImageReader.camera_model " + camera + " \
        --SiftExtraction.use_gpu " + str(use_gpu)
    exit_code = os.system(feat_extracton_cmd)
    if exit_code != 0:
        logging.error(f"Feature extraction failed with code {exit_code}. Exiting.")
        exit(exit_code)

    ## Feature matching
    feat_matching_cmd = colmap_command + " exhaustive_matcher \
        --database_path " + source_path + "/distorted/database.db \
        --SiftMatching.use_gpu " + str(use_gpu)
    exit_code = os.system(feat_matching_cmd)
    if exit_code != 0:
        logging.error(f"Feature matching failed with code {exit_code}. Exiting.")
        exit(exit_code)

    ### Bundle adjustment
    # The default Mapper tolerance is unnecessarily large,
    # decreasing it speeds up bundle adjustment steps.
    mapper_cmd = (colmap_command + " mapper \
        --database_path " + source_path + "/distorted/database.db \
        --image_path "  + source_path + "/images \
        --output_path "  + source_path + "/distorted/sparse \
        --Mapper.ba_global_function_tolerance=0.000001")
    exit_code = os.system(mapper_cmd)
    if exit_code != 0:
        logging.error(f"Mapper failed with code {exit_code}. Exiting.")
        exit(exit_code)

    ### Convert the model to a text file
    os.makedirs(source_path + "/sparse", exist_ok=True)
    convert_cmd = colmap_command + " model_converter \
        --input_path " + source_path + "/distorted/sparse/0 \
        --output_path " + source_path + "/sparse \
        --output_type TXT"
    exit_code = os.system(convert_cmd)
    if exit_code != 0:
        logging.error(f"Model conversion failed with code {exit_code}. Exiting.")
        exit(exit_code)

    ### Delete the distorted folder
    os.system("rm -r " + source_path + "/distorted")
# Out:
# I20241015 07:20:12.052548 106817 misc.cc:198]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I20241015 07:20:12.092305 106842 sift.cc:716] Creating SIFT GPU feature extractor
# I20241015 07:20:12.195067 106843 feature_extraction.cc:257] Processed file [1/10]
# I20241015 07:20:12.195111 106843 feature_extraction.cc:260]   Name:            0.png
# I20241015 07:20:12.195120 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.195127 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.195133 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.195145 106843 feature_extraction.cc:296]   Features:        2249
# I20241015 07:20:12.543146 106843 feature_extraction.cc:257] Processed file [2/10]
# I20241015 07:20:12.543226 106843 feature_extraction.cc:260]   Name:            1.png
# I20241015 07:20:12.543241 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.543254 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.543268 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.543292 106843 feature_extraction.cc:296]   Features:        2370
# I20241015 07:20:12.544334 106843 feature_extraction.cc:257] Processed file [3/10]
# I20241015 07:20:12.544373 106843 feature_extraction.cc:260]   Name:            2.png
# I20241015 07:20:12.544379 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.544385 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.544390 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.544400 106843 feature_extraction.cc:296]   Features:        2757
# I20241015 07:20:12.564924 106843 feature_extraction.cc:257] Processed file [4/10]
# I20241015 07:20:12.564963 106843 feature_extraction.cc:260]   Name:            3.png
# I20241015 07:20:12.564967 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.564973 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.564978 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.564985 106843 feature_extraction.cc:296]   Features:        2500
# I20241015 07:20:12.585341 106843 feature_extraction.cc:257] Processed file [5/10]
# I20241015 07:20:12.585405 106843 feature_extraction.cc:260]   Name:            4.png
# I20241015 07:20:12.585410 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.585422 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.585425 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.585433 106843 feature_extraction.cc:296]   Features:        2169
# I20241015 07:20:12.606573 106843 feature_extraction.cc:257] Processed file [6/10]
# I20241015 07:20:12.606629 106843 feature_extraction.cc:260]   Name:            5.png
# I20241015 07:20:12.606635 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.606640 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.606644 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.606652 106843 feature_extraction.cc:296]   Features:        2519
# I20241015 07:20:12.626935 106843 feature_extraction.cc:257] Processed file [7/10]
# I20241015 07:20:12.626983 106843 feature_extraction.cc:260]   Name:            6.png
# I20241015 07:20:12.626991 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.626994 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.626999 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.627009 106843 feature_extraction.cc:296]   Features:        2702
# I20241015 07:20:12.648205 106843 feature_extraction.cc:257] Processed file [8/10]
# I20241015 07:20:12.648236 106843 feature_extraction.cc:260]   Name:            7.png
# I20241015 07:20:12.648241 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.648244 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.648248 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.648263 106843 feature_extraction.cc:296]   Features:        2824
# I20241015 07:20:12.669615 106843 feature_extraction.cc:257] Processed file [9/10]
# I20241015 07:20:12.669679 106843 feature_extraction.cc:260]   Name:            left.png
# I20241015 07:20:12.669684 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.669688 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.669693 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.669704 106843 feature_extraction.cc:296]   Features:        2921
# I20241015 07:20:12.692312 106843 feature_extraction.cc:257] Processed file [10/10]
# I20241015 07:20:12.692350 106843 feature_extraction.cc:260]   Name:            right.png
# I20241015 07:20:12.692355 106843 feature_extraction.cc:286]   Dimensions:      1280 x 720
# I20241015 07:20:12.692360 106843 feature_extraction.cc:289]   Camera:          #1 - PINHOLE
# I20241015 07:20:12.692376 106843 feature_extraction.cc:292]   Focal Length:    1536.00px
# I20241015 07:20:12.692385 106843 feature_extraction.cc:296]   Features:        2692
# I20241015 07:20:12.706921 106817 timer.cc:91] Elapsed time: 0.011 [minutes]
# I20241015 07:20:13.012629 106870 misc.cc:198]
# ==============================================================================
# Feature matching
# ==============================================================================
# I20241015 07:20:13.055892 106871 sift.cc:1451] Creating SIFT GPU feature matcher
# I20241015 07:20:13.066377 106870 pairing.cc:168] Generating exhaustive image pairs...
# I20241015 07:20:13.066527 106870 pairing.cc:202] Matching block [1/1, 1/1]
# I20241015 07:20:14.253225 106870 feature_matching.cc:46]  in 1.187s
# I20241015 07:20:14.255282 106870 timer.cc:91] Elapsed time: 0.021 [minutes]
# I20241015 07:20:14.516106 106953 incremental_mapper.cc:225] Loading database
# I20241015 07:20:14.521659 106953 database_cache.cc:65] Loading cameras...
# I20241015 07:20:14.521814 106953 database_cache.cc:75]  1 in 0.000s
# I20241015 07:20:14.521862 106953 database_cache.cc:83] Loading matches...
# I20241015 07:20:14.523025 106953 database_cache.cc:89]  44 in 0.001s
# I20241015 07:20:14.523072 106953 database_cache.cc:105] Loading images...
# I20241015 07:20:14.528378 106953 database_cache.cc:155]  10 in 0.005s (connected 10)
# I20241015 07:20:14.528484 106953 database_cache.cc:166] Building correspondence graph...
# I20241015 07:20:14.537876 106953 database_cache.cc:195]  in 0.009s (ignored 0)
# I20241015 07:20:14.537983 106953 timer.cc:91] Elapsed time: 0.000 [minutes]
# I20241015 07:20:14.540339 106953 incremental_mapper.cc:265] Finding good initial image pair
# I20241015 07:20:14.645304 106953 incremental_mapper.cc:289] Initializing with image pair #3 and #2
# I20241015 07:20:14.656383 106953 incremental_mapper.cc:294] Global bundle adjustment
# I20241015 07:20:15.640136 106953 incremental_mapper.cc:375] Registering image #4 (3)
# I20241015 07:20:15.640309 106953 incremental_mapper.cc:378] => Image sees 360 / 1074 points
# I20241015 07:20:16.370621 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:16.469933 106953 incremental_mapper.cc:375] Registering image #1 (4)
# I20241015 07:20:16.469959 106953 incremental_mapper.cc:378] => Image sees 365 / 668 points
# I20241015 07:20:16.547459 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:16.589138 106953 incremental_mapper.cc:375] Registering image #5 (5)
# I20241015 07:20:16.589166 106953 incremental_mapper.cc:378] => Image sees 320 / 723 points
# I20241015 07:20:16.657060 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:16.704499 106953 incremental_mapper.cc:375] Registering image #6 (6)
# I20241015 07:20:16.704526 106953 incremental_mapper.cc:378] => Image sees 359 / 889 points
# I20241015 07:20:17.040405 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:17.586467 106953 incremental_mapper.cc:375] Registering image #7 (7)
# I20241015 07:20:17.586639 106953 incremental_mapper.cc:378] => Image sees 432 / 993 points
# I20241015 07:20:18.050110 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:18.623214 106953 incremental_mapper.cc:375] Registering image #8 (8)
# I20241015 07:20:18.623253 106953 incremental_mapper.cc:378] => Image sees 563 / 925 points
# I20241015 07:20:18.724459 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:18.813230 106953 incremental_mapper.cc:375] Registering image #9 (9)
# I20241015 07:20:18.813259 106953 incremental_mapper.cc:378] => Image sees 269 / 364 points
# I20241015 07:20:18.869851 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:18.973055 106953 incremental_mapper.cc:375] Registering image #10 (10)
# I20241015 07:20:18.973089 106953 incremental_mapper.cc:378] => Image sees 53 / 88 points
# I20241015 07:20:19.037074 106953 incremental_mapper.cc:41] Retriangulation and Global bundle adjustment
# I20241015 07:20:19.133517 106953 timer.cc:91] Elapsed time: 0.077 [minutes]

# %%
# pycolmap = 0.4.0
from aruco_estimator.aruco_scale_factor import ArucoScaleFactor
from colmap_wrapper.colmap import COLMAP
aruco_size = 0.186 # the size of the aruco marker in meters

# Load Colmap project folder
project = COLMAP(project_path=source_path)

# Init & run pose estimation of corners in 3D & estimate mean L2 distance between the four aruco corners
aruco_scale_factor = ArucoScaleFactor(photogrammetry_software=project, aruco_size=aruco_size)
aruco_distance, aruco_corners_3d = aruco_scale_factor.run()
print('Size of the unscaled aruco markers: ', aruco_distance)

# Calculate scaling factor, apply it to the scene and save scaled point cloud
dense, scale_factor = aruco_scale_factor.apply() 
print('Point cloud and poses are scaled by: ', scale_factor)
print('Size of the scaled (true to scale) aruco markers in meters: ', aruco_distance * scale_factor)

# Write Data
aruco_scale_factor.write_data()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D WARNING] Read PLY failed: unable to open file: ../../example_data/fused.ply
# Num process:  12
# RPly: Unable to open file
# 100%|██████████| 10/10 [00:00<00:00, 54.64it/s]
# Size of the unscaled aruco markers:  2.1843546796395974
# Point cloud and poses are scaled by:  0.08515100671777746
# Size of the scaled (true to scale) aruco markers in meters:  0.186
